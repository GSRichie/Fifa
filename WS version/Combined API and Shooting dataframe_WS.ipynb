# %%
import requests
from bs4 import BeautifulSoup as bs
import csv
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import pprint
import sys

# %%
base_url="https://www.foxsports.com/soccer/stats?competition=2&season=20180&category=STANDARD&pos=0&team=0&isOpp=0&sort=3&sortOrder=0&page="
player_list=[]
player_goals=[]
player_SOG=[]
player_shoot=[]
player_club=[]
club_acronym=[]

# %%
for i in range (1,10):
    url=base_url+str(i)
    response=requests.get(url)
    soup=bs(response.text, "html.parser")
    player_name_list_box=soup.find_all("a", class_="wisbb_fullPlayer")
    player_goals_box=soup.find_all("td", class_="wisbb_priorityColumn wisbb_selected")
    player_sog_box=soup.find_all("td", class_="wisbb_priorityColumn")
    player_shoot_list=soup.find_all("td", class_=None)
    player_club_box=soup.find_all("span",class_="wisbb_tableAbbrevLink")
    
    #player name
    for player in player_name_list_box:
        player_list.append(player.find("span").text)
        
    #player goals
    for goal in player_goals_box:
        player_goals.append(goal.text)
        
    #player shoot on goals
    for i in range(1,len(player_sog_box)+1):
        if not i%4:
            player_SOG.append(player_sog_box[i-1].text)
            
    #player shoots
    for i in range(1, len(player_shoot_list)+1):
        if i%5==3:
            player_shoot.append(player_shoot_list[i-1].text)
            
    #player club acronym, if player has no club (50 examples), use "None"
    for club in player_club_box:
        if len(list(club.text.replace("\n","")))<3:
            player_club.append("None")
        else:
            player_club.append(club.text.replace("\n","").strip())

# %%
df=pd.DataFrame({"FullName":player_list,
                 "Goals":player_goals,
                 "ShootOnGoals":player_SOG,
                 "Shoots":player_shoot,
                 "PlayerClub":player_club
                            })

# %%
last_name=[]
first_name=[]

# %%
#extract first name and last name, if only first name is shown (for some cases), use "Unknown" for last name
for name in df["FullName"]:
    if len(name.split(","))==2:
        last_name.append(name.split(",")[0].strip()) 
        first_name.append(name.split(",")[1].strip())
    if len(name.split(","))==1:
        last_name.append("Unknown")
        first_name.append(name.split(",")[0].strip())

# %%
df["LastName"]=last_name
df["FirstName"]=first_name

# %%
club_acronym=list(set(player_club))
club_acronym.remove("None")
print(club_acronym)
# Out:
# ['BET', 'HUE', 'ESP', 'EIB', 'BAR', 'SEV', 'VAL', 'ALA', 'VLD', 'CEL', 'LGN', 'RMD', 'GET', 'GIR', 'ATH', 'RV', 'VIL', 'RSO', 'ATL', 'LEV']

# %%
dic_club1={
        "LGN":"CD Leganés",
        "ATH":"Athletic Club",
        "ALA":"D. Alavés",
        "CEL":"RC Celta",
        "BET":"Real Betis",
        "VIL":"Villarreal CF",
        "GIR":"Girona FC",
        "LEV":"Levante UD",
        "ESP":"RCD Espanyol",
        "GET":"Getafe CF",
        "EIB":"SD Eibar",
        "RMD":"Real Madrid",
        "BAR":"FC Barcelona",
        "VAL":"Valencia CF",
        "HUE":"SD Huesca",
        "SEV":"Sevilla FC",
        "VLD":"R. Valladolid CF",
        "RV":"Rayo Vallecano",
        "ATL":"Atlético Madrid",
        "RSO":"Real Sociedad",
}

# %%
df['ForKey'] = df['FirstName'].str[:3] + df['LastName'].str[:3] + df['PlayerClub'].str[:3]
df.to_csv("Performance_La_Liga.csv")

# %%
#continue with API
df.head()
# Out:
#             FullName Goals ShootOnGoals Shoots PlayerClub  LastName  \
# 0      Messi, Lionel     9           22     47        BAR     Messi
# 1       Suarez, Luis     9           21     45        BAR    Suarez
# 2  Stuani, Cristhian     8           11     20        GIR    Stuani
# 3        Aspas, Iago     8           15     29        CEL     Aspas
# 4    Iglesias, Borja     7           18     32        ESP  Iglesias
#
#    FirstName     ForKey
# 0     Lionel  LioMesBAR
# 1       Luis  LuiSuaBAR
# 2  Cristhian  CriStuGIR
# 3       Iago  IagAspCEL
# 4      Borja  BorIglESP

# %%
url = "https://www.easports.com/fifa/ultimate-team/api/fut/item?"
league = "53"
page = 1
query_url = f"{url}league={league}&page={page}"

# Get FIFA Ultimate-team data
fifa_response = requests.get(query_url)
fifa_json = fifa_response.json()
totalPages = fifa_json["totalPages"]
playersCount = fifa_json["count"]
#playersCount

# %%
# Structuring DataFrame0
#[players.append(fifa_json["items"][i]["firstName"]) for i in range(playersCount)]
players2 = []
for p in range(totalPages):
    pg = p+1
    query_url = f"{url}league={league}&page={pg}"
    fifa_response = requests.get(query_url)
    fifa_json = fifa_response.json()
    playersCount = fifa_json["count"]
    for i in range(playersCount):
        players2.append([fifa_json["items"][i]["firstName"],fifa_json["items"][i]["lastName"],fifa_json["items"][i]["nation"]["name"],fifa_json["items"][i]["club"]["name"],fifa_json["items"][i]["positionFull"],fifa_json["items"][i]["age"],fifa_json["items"][i]["acceleration"],fifa_json["items"][i]["aggression"],fifa_json["items"][i]["finishing"],fifa_json["items"][i]["freekickaccuracy"],fifa_json["items"][i]["longpassing"],fifa_json["items"][i]["longshots"],fifa_json["items"][i]["penalties"],fifa_json["items"][i]["shortpassing"],fifa_json["items"][i]["sprintspeed"],fifa_json["items"][i]["quality"]])
players = pd.DataFrame(players2, columns=['FirstName','LastName','Country','Club','Position','Age','Acceleration','Aggression','Finishing','FreeKickAccuracy','LongPassing','LongShots','Penalties','ShortPassing','SprintSpeed','Quality'])

# %%
#make a list of full club name
club_fullname=[]
for k,v in dic_club1.items():
    club_fullname.append(v)

# %%
#only select clubs in La Liga
df_player=players.loc[players["Club"].isin(club_fullname)]

# %%
#replace the club full name with acronym
dic_club2={
        "CD Leganés":"LGN",
        "Athletic Club":"ATH",
        "D. Alavés":"ALA",
        "RC Celta":"CEL",
        "Real Betis":"BET",
        "Villarreal CF":"VIL",
        "Girona FC":"GIR",
        "Levante UD":"LEV",
        "RCD Espanyol":"ESP",
        "Getafe CF":"GET",
        "SD Eibar":"EIB",
        "Real Madrid":"RMD",
        "FC Barcelona":"BAR",
        "Valencia CF":"VAL",
        "SD Huesca":"HUE",
        "Sevilla FC":"SEV",
        "R. Valladolid CF":"VLD",
        "Rayo Vallecano":"RV",
        "Atlético Madrid":"ATL",
        "Real Sociedad":"RSO",
}

df_player["Club"]=df_player["Club"].apply(lambda x:dic_club2[x])
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:25: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df_player['ForKey'] = df_player['FirstName'].str[:3] + df_player['LastName'].str[:3] + df_player['Club'].str[:3]
df_player.head()
# Out:
# /anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#   FirstName      LastName    Country Club           Position  Age  \
# 0      Luka        Modrić    Croatia  RMD  Centre Midfielder   33
# 1    Lionel         Messi  Argentina  BAR     Centre Forward   31
# 2    Sergio  Ramos García      Spain  RMD        Centre Back   32
# 3   Raphaël        Varane     France  RMD        Centre Back   25
# 4    Lionel         Messi  Argentina  BAR            Striker   31
#
#    Acceleration  Aggression  Finishing  FreeKickAccuracy  LongPassing  \
# 0            94          83         89                85           96
# 1            99          66         99                99           96
# 2            86          96         76                83           90
# 3            88          88         62                72           99
# 4            93          51         97                98           90
#
#    LongShots  Penalties  ShortPassing  SprintSpeed Quality     ForKey
# 0         99         99            99           85    gold  LukModRMD
# 1         99         81            99           94    gold  LioMesBAR
# 2         69         86            97           85    gold  SerRamRMD
# 3         82         66            99           91    gold  RapVarRMD
# 4         96         76            94           87    gold  LioMesBAR

# %%
df_player.to_csv("FIFA Ultimate Team Data")

# %%
df_merged=pd.merge(df, df_player, on='ForKey', how='outer')
df_merged.dropna(how="any")
# Out:
#                   FullName Goals ShootOnGoals Shoots PlayerClub  LastName_x  \
# 0            Messi, Lionel     9           22     47        BAR       Messi
# 1            Messi, Lionel     9           22     47        BAR       Messi
# 2            Messi, Lionel     9           22     47        BAR       Messi
# 3            Messi, Lionel     9           22     47        BAR       Messi
# 4            Messi, Lionel     9           22     47        BAR       Messi
# 5            Messi, Lionel     9           22     47        BAR       Messi
# 7        Stuani, Cristhian     8           11     20        GIR      Stuani
# 8        Stuani, Cristhian     8           11     20        GIR      Stuani
# 9        Stuani, Cristhian     8           11     20        GIR      Stuani
# 10       Stuani, Cristhian     8           11     20        GIR      Stuani
# 11       Stuani, Cristhian     8           11     20        GIR      Stuani
# 12             Aspas, Iago     8           15     29        CEL       Aspas
# 13             Aspas, Iago     8           15     29        CEL       Aspas
# 14             Aspas, Iago     8           15     29        CEL       Aspas
# 15             Aspas, Iago     8           15     29        CEL       Aspas
# 16             Aspas, Iago     8           15     29        CEL       Aspas
# 17         Iglesias, Borja     7           18     32        ESP    Iglesias
# 19      Ben Yedder, Wissam     6           11     25        SEV  Ben Yedder
# 20      Ben Yedder, Wissam     6           11     25        SEV  Ben Yedder
# 21      Ben Yedder, Wissam     6           11     25        SEV  Ben Yedder
# 23            Marti, Roger     6            9     22        LEV       Marti
# 24          Benzema, Karim     5           12     32        RMD     Benzema
# 25          Benzema, Karim     5           12     32        RMD     Benzema
# 26          Benzema, Karim     5           12     32        RMD     Benzema
# 27           Muniain, Iker     4            4      6        ATH     Muniain
# 29      Coutinho, Philippe     4           16     29        BAR    Coutinho
# 30      Coutinho, Philippe     4           16     29        BAR    Coutinho
# 31      Coutinho, Philippe     4           16     29        BAR    Coutinho
# 32        Dembele, Ousmane     4            9     21        BAR     Dembele
# 33        Dembele, Ousmane     4            9     21        BAR     Dembele
# ..                     ...   ...          ...    ...        ...         ...
# 511     Piccini, Cristiano     0            0      4        VAL     Piccini
# 512       Reguilon, Sergio     0            0      0        RMD    Reguilon
# 514        Arias, Santiago     0            0      3        ATL       Arias
# 515        Arias, Santiago     0            0      3        ATL       Arias
# 516        Arias, Santiago     0            0      3        ATL       Arias
# 517        Jensen, Mathias     0            0      2        CEL      Jensen
# 518         Alonso, Junior     0            2      3        CEL      Alonso
# 522  Jovanovic, Aleksandar     0            0      0        HUE   Jovanovic
# 525           Rolan, Diego     0            0      2        LGN       Rolan
# 526     En-Nesyri, Youssef     0            3     14        LGN   En-Nesyri
# 527        Santos, Michael     0            3      8        LGN      Santos
# 528            Nyom, Allan     0            0      0        LGN        Nyom
# 529        Omeruo, Kenneth     0            0      0        LGN      Omeruo
# 530       Roberts, Patrick     0            2      3        GIR     Roberts
# 531        Doumbia, Seydou     0            0      1        GIR     Doumbia
# 532        Doumbia, Seydou     0            0      1        GIR     Doumbia
# 533       De Blasis, Pablo     0            2      4        EIB   De Blasis
# 534           Bigas, Pedro     0            0      2        EIB       Bigas
# 535         Miquel, Ignasi     0            0      0        GET      Miquel
# 538       Dwamena, Raphael     0            0      0        LEV     Dwamena
# 539       Vukcevic, Nikola     0            0      0        LEV    Vukcevic
# 540          Prcic, Sanjin     0            0      4        LEV       Prcic
# 541        Kalinic, Nikola     0            1      4        ATL     Kalinic
# 542        Kalinic, Nikola     0            1      4        ATL     Kalinic
# 543       Gonalons, Maxime     0            0      0        SEV    Gonalons
# 546      Courtois, Thibaut     0            0      0        RMD    Courtois
# 547      Courtois, Thibaut     0            0      0        RMD    Courtois
# 552       Elustondo, Gorka     0            0      2         RV   Elustondo
# 558          Muniesa, Marc     0            0      2        GIR     Muniesa
# 560            Milla, Pere     0            0      4        EIB       Milla
#
#     FirstName_x     ForKey FirstName_y          LastName_y   ...     \
# 0        Lionel  LioMesBAR      Lionel               Messi   ...
# 1        Lionel  LioMesBAR      Lionel               Messi   ...
# 2        Lionel  LioMesBAR      Lionel               Messi   ...
# 3        Lionel  LioMesBAR      Lionel               Messi   ...
# 4        Lionel  LioMesBAR      Lionel               Messi   ...
# 5        Lionel  LioMesBAR      Lionel               Messi   ...
# 7     Cristhian  CriStuGIR   Cristhian              Stuani   ...
# 8     Cristhian  CriStuGIR   Cristhian              Stuani   ...
# 9     Cristhian  CriStuGIR   Cristhian              Stuani   ...
# 10    Cristhian  CriStuGIR   Cristhian              Stuani   ...
# 11    Cristhian  CriStuGIR   Cristhian              Stuani   ...
# 12         Iago  IagAspCEL        Iago        Aspas Juncal   ...
# 13         Iago  IagAspCEL        Iago        Aspas Juncal   ...
# 14         Iago  IagAspCEL        Iago        Aspas Juncal   ...
# 15         Iago  IagAspCEL        Iago        Aspas Juncal   ...
# 16         Iago  IagAspCEL        Iago        Aspas Juncal   ...
# 17        Borja  BorIglESP       Borja    Iglesias Quintas   ...
# 19       Wissam  WisBenSEV      Wissam          Ben Yedder   ...
# 20       Wissam  WisBenSEV      Wissam          Ben Yedder   ...
# 21       Wissam  WisBenSEV      Wissam          Ben Yedder   ...
# 23        Roger  RogMarLEV       Roger      Martí Salvador   ...
# 24        Karim  KarBenRMD       Karim             Benzema   ...
# 25        Karim  KarBenRMD       Karim             Benzema   ...
# 26        Karim  KarBenRMD       Karim             Benzema   ...
# 27         Iker  IkeMunATH        Iker        Muniain Goñi   ...
# 29     Philippe  PhiCouBAR    Philippe    Coutinho Correia   ...
# 30     Philippe  PhiCouBAR    Philippe    Coutinho Correia   ...
# 31     Philippe  PhiCouBAR    Philippe    Coutinho Correia   ...
# 32      Ousmane  OusDemBAR     Ousmane             Dembélé   ...
# 33      Ousmane  OusDemBAR     Ousmane             Dembélé   ...
# ..          ...        ...         ...                 ...   ...
# 511   Cristiano  CriPicVAL   Cristiano             Piccini   ...
# 512      Sergio  SerRegRMD      Sergio  Reguilón Rodríguez   ...
# 514    Santiago  SanAriATL    Santiago               Arias   ...
# 515    Santiago  SanAriATL    Santiago               Arias   ...
# 516    Santiago  SanAriATL    Santiago               Arias   ...
# 517     Mathias  MatJenCEL     Mathias              Jensen   ...
# 518      Junior  JunAloCEL      Junior              Alonso   ...
# 522  Aleksandar  AleJovHUE  Aleksandar           Jovanović   ...
# 525       Diego  DieRolLGN       Diego               Rolán   ...
# 526     Youssef  YouEn-LGN     Youssef           En-Nesyri   ...
# 527     Michael  MicSanLGN     Michael              Santos   ...
# 528       Allan  AllNyoLGN       Allan                Nyom   ...
# 529     Kenneth  KenOmeLGN     Kenneth              Omeruo   ...
# 530     Patrick  PatRobGIR     Patrick             Roberts   ...
# 531      Seydou  SeyDouGIR      Seydou             Doumbia   ...
# 532      Seydou  SeyDouGIR      Seydou             Doumbia   ...
# 533       Pablo  PabDe EIB       Pablo           De Blasis   ...
# 534       Pedro  PedBigEIB       Pedro          Bigas Rigo   ...
# 535      Ignasi  IgnMiqGET      Ignasi       Miquel i Pons   ...
# 538     Raphael  RapDwaLEV     Raphael             Dwamena   ...
# 539      Nikola  NikVukLEV      Nikola            Vukčević   ...
# 540      Sanjin  SanPrcLEV      Sanjin               Prcić   ...
# 541      Nikola  NikKalATL      Nikola             Kalinić   ...
# 542      Nikola  NikKalATL      Nikola             Kalinić   ...
# 543      Maxime  MaxGonSEV      Maxime            Gonalons   ...
# 546     Thibaut  ThiCouRMD     Thibaut            Courtois   ...
# 547     Thibaut  ThiCouRMD     Thibaut            Courtois   ...
# 552       Gorka   GorEluRV       Gorka    Elustondo Urkola   ...
# 558        Marc  MarMunGIR        Marc    Muniesa Martínez   ...
# 560        Pere  PerMilEIB        Pere          Milla Peña   ...
#
#     Acceleration Aggression Finishing  FreeKickAccuracy  LongPassing  \
# 0           99.0       66.0      99.0              99.0         96.0
# 1           93.0       51.0      97.0              98.0         90.0
# 2           93.0       51.0      97.0              98.0         90.0
# 3           92.0       48.0      96.0              95.0         87.0
# 4           92.0       50.0      96.0              96.0         88.0
# 5           91.0       48.0      95.0              94.0         87.0
# 7           73.0       81.0      86.0              62.0         71.0
# 8           73.0       81.0      86.0              62.0         71.0
# 9           71.0       79.0      84.0              59.0         67.0
# 10          71.0       79.0      84.0              59.0         67.0
# 11          67.0       77.0      80.0              57.0         65.0
# 12          87.0       65.0      93.0              79.0         67.0
# 13          87.0       65.0      93.0              79.0         67.0
# 14          86.0       63.0      92.0              77.0         65.0
# 15          86.0       63.0      92.0              77.0         65.0
# 16          85.0       63.0      90.0              76.0         64.0
# 17          59.0       42.0      83.0              36.0         64.0
# 19          92.0       60.0      90.0              82.0         71.0
# 20          90.0       58.0      88.0              81.0         70.0
# 21          87.0       55.0      83.0              76.0         66.0
# 23          78.0       65.0      78.0              46.0         48.0
# 24          79.0       69.0      82.0              76.0         57.0
# 25          77.0       65.0      78.0              73.0         55.0
# 26          76.0       65.0      78.0              73.0         55.0
# 27          83.0       66.0      76.0              69.0         65.0
# 29          91.0       57.0      78.0              88.0         82.0
# 30          90.0       55.0      77.0              87.0         81.0
# 31          89.0       55.0      77.0              86.0         81.0
# 32          93.0       56.0      80.0              67.0         73.0
# 33          93.0       56.0      80.0              67.0         73.0
# ..           ...        ...       ...               ...          ...
# 511         74.0       74.0      32.0              37.0         59.0
# 512         67.0       55.0      22.0              39.0         25.0
# 514         87.0       84.0      52.0              61.0         82.0
# 515         84.0       80.0      51.0              54.0         74.0
# 516         84.0       79.0      51.0              54.0         73.0
# 517         74.0       65.0      65.0              66.0         75.0
# 518         58.0       76.0      38.0              27.0         63.0
# 522         22.0       20.0       8.0              10.0         15.0
# 525         74.0       64.0      77.0              70.0         62.0
# 526         75.0       37.0      73.0              47.0         46.0
# 527         77.0       80.0      73.0              62.0         57.0
# 528         67.0       80.0      27.0              30.0         64.0
# 529         67.0       76.0      22.0              23.0         60.0
# 530         79.0       38.0      68.0              49.0         65.0
# 531         89.0       66.0      81.0              75.0         68.0
# 532         87.0       60.0      73.0              69.0         63.0
# 533         81.0       74.0      72.0              62.0         66.0
# 534         71.0       83.0      49.0              43.0         60.0
# 535         64.0       75.0      18.0              24.0         58.0
# 538         76.0       47.0      74.0              42.0         41.0
# 539         64.0       85.0      38.0              64.0         70.0
# 540         62.0       70.0      61.0              73.0         73.0
# 541         67.0       68.0      84.0              54.0         48.0
# 542         67.0       68.0      83.0              54.0         48.0
# 543         65.0       83.0      55.0              57.0         74.0
# 546         47.0       23.0      14.0              20.0         35.0
# 547         46.0       23.0      14.0              20.0         35.0
# 552         49.0       88.0      59.0              80.0         73.0
# 558         42.0       78.0      42.0              40.0         56.0
# 560         78.0       45.0      75.0              58.0         60.0
#
#      LongShots  Penalties  ShortPassing  SprintSpeed  Quality
# 0         99.0       81.0          99.0         94.0     gold
# 1         96.0       76.0          94.0         87.0     gold
# 2         96.0       76.0          94.0         87.0     gold
# 3         95.0       75.0          91.0         86.0     gold
# 4         95.0       75.0          92.0         86.0     gold
# 5         94.0       75.0          90.0         86.0     gold
# 7         80.0       86.0          81.0         69.0     gold
# 8         80.0       86.0          81.0         69.0     gold
# 9         78.0       84.0          77.0         67.0     gold
# 10        78.0       84.0          77.0         67.0     gold
# 11        75.0       80.0          74.0         64.0     gold
# 12        84.0       84.0          85.0         79.0     gold
# 13        84.0       84.0          85.0         79.0     gold
# 14        83.0       83.0          83.0         78.0     gold
# 15        83.0       83.0          83.0         78.0     gold
# 16        82.0       82.0          81.0         78.0     gold
# 17        75.0       78.0          68.0         65.0     gold
# 19        75.0       76.0          81.0         87.0     gold
# 20        73.0       74.0          80.0         85.0     gold
# 21        69.0       70.0          75.0         83.0     gold
# 23        72.0       78.0          71.0         79.0     gold
# 24        79.0       87.0          86.0         79.0     gold
# 25        75.0       83.0          83.0         77.0     gold
# 26        75.0       82.0          82.0         76.0     gold
# 27        72.0       61.0          75.0         75.0     gold
# 29        95.0       71.0          90.0         76.0     gold
# 30        94.0       70.0          89.0         75.0     gold
# 31        93.0       70.0          88.0         75.0     gold
# 32        69.0       78.0          80.0         89.0     gold
# 33        69.0       78.0          80.0         89.0     gold
# ..         ...        ...           ...          ...      ...
# 511       35.0       35.0          73.0         76.0     gold
# 512       33.0       42.0          54.0         62.0   bronze
# 514       51.0       58.0          83.0         90.0     gold
# 515       50.0       57.0          75.0         87.0     gold
# 516       50.0       56.0          74.0         86.0     gold
# 517       69.0       69.0          76.0         74.0     gold
# 518       46.0       33.0          65.0         64.0   silver
# 522        8.0       14.0          22.0         22.0   silver
# 525       63.0       75.0          74.0         78.0     gold
# 526       68.0       59.0          63.0         77.0   silver
# 527       69.0       70.0          65.0         75.0   silver
# 528       66.0       37.0          63.0         76.0   silver
# 529       31.0       35.0          63.0         75.0   silver
# 530       67.0       62.0          73.0         74.0   silver
# 531       75.0       88.0          76.0         94.0     gold
# 532       68.0       80.0          70.0         91.0     gold
# 533       72.0       79.0          74.0         75.0     gold
# 534       47.0       48.0          72.0         72.0     gold
# 535       21.0       43.0          69.0         66.0   silver
# 538       67.0       66.0          58.0         82.0   silver
# 539       61.0       53.0          79.0         56.0     gold
# 540       60.0       63.0          76.0         65.0   silver
# 541       60.0       70.0          73.0         74.0     gold
# 542       60.0       70.0          72.0         73.0     gold
# 543       59.0       68.0          74.0         55.0     gold
# 546       17.0       27.0          33.0         53.0     gold
# 547       17.0       27.0          33.0         52.0     gold
# 552       74.0       67.0          76.0         61.0   silver
# 558       37.0       50.0          73.0         59.0   silver
# 560       70.0       62.0          67.0         76.0   silver
#
# [391 rows x 24 columns]

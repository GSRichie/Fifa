# %%
import os
from bs4 import BeautifulSoup as bs
import requests
from pprint import pprint
import pandas as pd

# %%
# URL of page to be scraped
url = 'https://www.easports.com/fifa/ultimate-team/api/fut/item?league=53&page=1'
response = requests.get(url)
soup = bs(response.text, 'lxml')
print(soup.prettify())
# Out:
# <html>
#  <body>
#   <p>
# ...

# %%
df = pd.read_csv("Players Ultimate-Team.csv")
df = pd.DataFrame(df)

# %%
df.head()
# Out:
#    Unnamed: 0 FirstName      LastName    Country          Club  \
# 0           0      Luka        Modrić    Croatia   Real Madrid
# 1           1    Lionel         Messi  Argentina  FC Barcelona
# 2           2    Sergio  Ramos García      Spain   Real Madrid
# 3           3   Raphaël        Varane     France   Real Madrid
# 4           4    Lionel         Messi  Argentina  FC Barcelona
#
#             Position  Age  Acceleration  Aggression  Finishing  \
# 0  Centre Midfielder   33            94          83         89
# 1     Centre Forward   31            99          66         99
# 2        Centre Back   32            86          96         76
# 3        Centre Back   25            88          88         62
# 4            Striker   31            93          51         97
#
#    FreeKickAccuracy  LongPassing  LongShots  Penalties  ShortPassing  \
# 0                85           96         99         99            99
# ...

# %%
df1 = pd.pivot_table(df, index=['LastName','FirstName', 'Club'], values=['Age','Acceleration','Aggression','FreeKickAccuracy','LongPassing','LongShots','Penalties','ShortPassing','SprintSpeed'])
df1.to_csv('C:/Users/Ex-Sell/Desktop/HMWRK_SS/Fifa/Players Ultimate-Team_agg.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-3bf2610927b9> in <module>
#       1 df1 = pd.pivot_table(df, index=['LastName','FirstName', 'Club'], values=['Age','Acceleration','Aggression','FreeKickAccuracy','LongPassing','LongShots','Penalties','ShortPassing','SprintSpeed'])
# ----> 2 df1.to_csv('C:/Users/Ex-Sell/Desktop/HMWRK_SS/Fifa/Players Ultimate-Team_agg.csv')
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, tupleize_cols, date_format, doublequote, escapechar, decimal)
#    1743                                  doublequote=doublequote,
#    1744                                  escapechar=escapechar, decimal=decimal)
# -> 1745         formatter.save()
#    1746
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.offsetbox import OffsetImage, AnnotationBbox
from matplotlib.cbook import get_sample_data

def main():
    x = np.linspace(0, 10, 20)
    y = np.cos(x)
    image_path = get_sample_data('C:/Users/Ex-Sell/Desktop/soccerball.png')
    fig, ax = plt.subplots()
    imscatter(x, y, image_path, zoom=0.1, ax=ax)
    ax.plot(x, y)
    plt.show()

def imscatter(x, y, image, ax=None, zoom=1):
    if ax is None:
        ax = plt.gca()
    try:
        image = plt.imread(image)
    except TypeError:
        # Likely already an array...
        pass
    im = OffsetImage(image, zoom=zoom)
    x, y = np.atleast_1d(x, y)
    artists = []
    for x0, y0 in zip(x, y):
        ab = AnnotationBbox(im, (x0, y0), xycoords='data', frameon=False)
        artists.append(ax.add_artist(ab))
    ax.update_datalim(np.column_stack([x, y]))
    ax.autoscale()
    return artists

main()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-d8575de1347e> in <module>
#      31     return artists
#      32
# ---> 33 main()
#
# <ipython-input-10-d8575de1347e> in main()
#       7     x = np.linspace(0, 10, 20)
#       8     y = np.cos(x)
# ----> 9     image_path = get_sample_data('C:/Users/Ex-Sell/Desktop/soccerball.png')
#      10     fig, ax = plt.subplots()
#      11     imscatter(x, y, image_path, zoom=0.1, ax=ax)
#
# ~\Anaconda3\lib\site-packages\matplotlib\cbook\__init__.py in get_sample_data(fname, asfileobj)
#     463             return gzip.open(path, mode)
#     464         else:
# --> 465             return open(path, mode)
#     466     else:
#     467         return path
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/Ex-Sell/Desktop/soccerball.png'

# %%
plt.show()
